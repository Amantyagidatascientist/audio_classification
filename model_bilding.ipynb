# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install librosa

# %%
pip install noisereduce

# %%
pip install resampy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display as ipd
import noisereduce as nr


# %matplotlib inline

# %%
file_path1= '/content/drive/MyDrive/UrbanSound8K/UrbanSound8K/audio/fold8/207214-2-0-126.wav'
y, sr = librosa.load(file_path1)

print(f"Sample rate: {sr}")
print(f"Audio shape: {y.shape}")

# %%
file_path2='/content/drive/MyDrive/UrbanSound8K/UrbanSound8K/audio/fold5/100032-3-0-0.wav'
y, sr = librosa.load(file_path2)

print(f"Sample rate: {sr}")
print(f"Audio shape: {y.shape}")

# %%
file_path= '/content/drive/MyDrive/UrbanSound8K/UrbanSound8K/audio'

# %%
import pandas as pd
import os
import librosa
metadata=pd.read_csv('/content/drive/MyDrive/UrbanSound8K/UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata.tail()
# Out:
#       slice_file_name   fsID       start         end  salience  fold  classID  \
# 8727  99812-1-2-0.wav  99812  159.522205  163.522205         2     7        1
# 8728  99812-1-3-0.wav  99812  181.142431  183.284976         2     7        1
# 8729  99812-1-4-0.wav  99812  242.691902  246.197885         2     7        1
# 8730  99812-1-5-0.wav  99812  253.209850  255.741948         2     7        1
# 8731  99812-1-6-0.wav  99812  332.289233  334.821332         2     7        1
#
#          class
# 8727  car_horn
# 8728  car_horn
# 8729  car_horn
# 8730  car_horn
# 8731  car_horn

# %% [markdown]
# **Extract** **Features**

# %% [markdown]
# MFCCs are a way to represent the important features of a sound, especially speech, in a form that computers can understand. They capture the unique characteristics of a sound, much like how a fingerprint captures the unique patterns of a finger. This makes them useful for tasks like recognizing who is speaking or what is being said

# %%
import librosa

librosa_audio_data,librosa_sample_rate=librosa.load(file_path1)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 173)

# %%
mfccs
# Out:
# array([[-255.05795   , -222.76495   , -229.04942   , ..., -203.67001   ,
#         -196.85176   , -209.62994   ],
#        [  99.780685  ,  100.02282   ,  106.256935  , ...,   83.46359   ,
#           94.52501   ,   89.41305   ],
#        [ -48.255737  ,  -45.52656   ,  -29.57716   , ...,  -50.454506  ,
#          -68.45357   ,  -68.5155    ],
#        ...,
#        [   2.051464  ,    2.9203377 ,    3.2099898 , ...,   -1.1559093 ,
#            0.46547616,    0.7810559 ],
#        [   2.9337716 ,   -1.3559061 ,   -1.8927739 , ...,   16.230251  ,
#            9.266466  ,    7.595415  ],
#        [   1.8099263 ,   -1.7420986 ,   -4.476653  , ...,   12.689402  ,
#            9.408958  ,    2.605987  ]], dtype=float32)

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

    return mfccs_scaled_features

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# %%
import librosa
import numpy as np

def features_extractor(file):
    audio, sample_rate = librosa.load(file, res_type='scipy')
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# %%
print(features_extractor(file_path2))
# Out:
# [-2.11018326e+02  6.12798882e+01 -1.21516464e+02 -6.20414124e+01
#  -1.26024799e+01 -3.10799007e+01 -2.69238615e+00  1.03976536e+01
#   1.42451410e+01  7.05815649e+00 -5.25782776e+00 -4.26351166e+00
#  -1.16294947e+01  4.63277197e+00 -1.23143232e+00 -5.64747286e+00
#  -1.37848730e+01 -2.16856265e+00 -1.36503983e+00  4.88993168e+00
#  -9.58780479e+00 -9.25276661e+00  7.02111578e+00 -4.28910112e+00
#  -4.83107662e+00 -1.22395730e+00 -2.55844355e+00  3.62625742e+00
#  -5.42467213e+00 -6.18278074e+00  1.56944597e+00  6.43726254e+00
#   1.70544356e-01  1.34898400e+00 -5.36486721e+00 -3.14576173e+00
#   3.27412605e+00 -1.77598989e+00 -5.67917407e-01  3.64136308e-01]

# %%
pip install noisereduce

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import librosa
import numpy as np

class AudioPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, max_len=376, target_sr=16000):
        self.max_len = max_len
        self.target_sr = target_sr

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        processed = []
        for file_name in X:
            audio, sr = librosa.load(file_name, res_type='scipy')
            audio_resampled = librosa.resample(audio, orig_sr=sr, target_sr=self.target_sr)
            reduced_noise = nr.reduce_noise(y=audio_resampled, sr=target_sr)
            mfccs = librosa.feature.mfcc(y=reduced_noise, sr=self.target_sr, n_mfcc=40)

            # Padding or truncating
            if mfccs.shape[1] < self.max_len:
                pad_width = self.max_len - mfccs.shape[1]
                mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
            else:
                mfccs = mfccs[:, :self.max_len]

            processed.append(mfccs.T)  # (time_steps, n_mfcc)
        return np.array(processed)

# %%
extractor = FeatureExtractor(max_len=376, target_sr=16000)

# %%
features = []
labels = []

for index_num, row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(file_path), 'fold'+str(row["fold"]), str(row["slice_file_name"]))
    class_label = row["class"]
    print(file_name)
    data = extractor(file_name)
    features.append(data)
    labels.append(class_label)

# Convert to arrays
X = np.array(features)  # Shape: (num_samples, time_steps, n_mfcc)
y = np.array(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-f72af37c8584> in <cell line: 0>()
#       3 extractor = FeatureExtractor(max_len=376, target_sr=16000)
#       4
# ----> 5 for index_num, row in tqdm(metadata.iterrows()):
#       6     file_name = os.path.join(os.path.abspath(file_path), 'fold'+str(row["fold"]), str(row["slice_file_name"]))
#       7     class_label = row["class"]
#
# NameError: name 'tqdm' is not defined

# %%
import numpy as np
import pickle

X = np.array(features)
y = np.array(labels)

with open('audio_data.pkl', 'wb') as f:
    pickle.dump({'X': X, 'y': y}, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fbf3271dd2e0> in <cell line: 0>()
#       2 import pickle
#       3
# ----> 4 X = np.array(features)  # Can be multi-dimensional
#       5 y = np.array(labels)
#       6
#
# NameError: name 'features' is not defined

# %%
# !cp audio_data.pkl /content/drive/MyDrive/
# !cp audio_data.pkl /content/drive/MyDrive/

# %%
import pickle

with open('/content/drive/MyDrive/audio_data.pkl', 'rb') as f:
    data = pickle.load(f)

X = data['X']
y = data['y']

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (8732, 376, 40)
# Shape of y: (8732,)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y_encoded = labelencoder.fit_transform(y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# !pip install keras-tuner --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense
from kerastuner import HyperModel
from kerastuner.tuners import RandomSearch

num_classes = 10

class AudioCNNHyperModel(HyperModel):
    def build(self, hp):
        model = Sequential()

        model.add(Conv2D(
            filters=hp.Choice('conv1_filters', values=[32, 64]),
            kernel_size=hp.Choice('conv1_kernel', values=[3, 5]),
            activation='relu',
            padding='same',
            input_shape=(376, 40, 1)
        ))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(
            filters=hp.Choice('conv2_filters', values=[64, 128]),
            kernel_size=hp.Choice('conv2_kernel', values=[3, 5]),
            activation='relu',
            padding='same'
        ))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Conv2D(
            filters=hp.Choice('conv3_filters', values=[128, 256]),
            kernel_size=hp.Choice('conv3_kernel', values=[3, 5]),
            activation='relu',
            padding='same'
        ))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Flatten())

        model.add(Dense(units=hp.Choice('dense_units', values=[128, 256, 512]), activation='relu'))
        model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Dense(num_classes, activation='softmax'))

        model.compile(
            optimizer=tf.keras.optimizers.Adam(
                hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        return model

# %%
tuner = RandomSearch(
    AudioCNNHyperModel(),
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=1,
    directory='audio_cnn_tuning',
    project_name='audio_classification'
)


X_train = X_train.reshape((X_train.shape[0], 376, 40, 1))

tuner.search(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)]
)
# Out:
# Trial 20 Complete [00h 03m 18s]
# val_accuracy: 0.6778811812400818
#
# Best val_accuracy So Far: 0.8647100925445557
# Total elapsed time: 00h 49m 59s

# %%
# !pip install scikeras

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(1)[0]

print("Best hyperparameters:", best_hyperparameters.values)

X_test = X_test.reshape((X_test.shape[0], 376, 40, 1))
val_loss, val_acc = best_model.evaluate(X_test, y_test)
print(f"Validation accuracy: {val_acc:.4f}")
# Out:
# Best hyperparameters: {'conv1_filters': 32, 'conv1_kernel': 5, 'conv2_filters': 128, 'conv2_kernel': 3, 'dropout_1': 0.2, 'conv3_filters': 128, 'conv3_kernel': 5, 'dropout_2': 0.2, 'dense_units': 512, 'dropout_3': 0.2, 'learning_rate': 0.00012093314183885964}
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8635 - loss: 0.4802
# Validation accuracy: 0.8552

# %%
from scikeras.wrappers import KerasClassifier


# Only needed if tuner returns raw Keras model
keras_clf = KerasClassifier(build_fn=lambda: best_model, epochs=1, verbose=0)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = best_model.fit(
    X_train, y_train,
    epochs=100,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 66ms/step - accuracy: 0.9491 - loss: 0.1457 - val_accuracy: 0.8074 - val_loss: 0.6397
# Epoch 2/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9606 - loss: 0.1161 - val_accuracy: 0.8332 - val_loss: 0.5758
# Epoch 3/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9606 - loss: 0.1135 - val_accuracy: 0.8525 - val_loss: 0.5291
# Epoch 4/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9678 - loss: 0.1015 - val_accuracy: 0.8203 - val_loss: 0.6078
# Epoch 5/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.9661 - loss: 0.0860 - val_accuracy: 0.8561 - val_loss: 0.5199
# Epoch 6/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9788 - loss: 0.0690 - val_accuracy: 0.8533 - val_loss: 0.5375
# Epoch 7/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9794 - loss: 0.0571 - val_accuracy: 0.8232 - val_loss: 0.6858
# Epoch 8/100
# ...

# %%
test_loss, test_acc = best_model.evaluate(X_test, y_test)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8567 - loss: 0.5588

# %%
print(test_loss, test_acc)
# Out:
# 0.5481544137001038 0.8483113646507263

# %%
history.history
# Out:
# {'accuracy': [0.9414817690849304,
#   0.9620615839958191,
#   0.9613457322120667,
#   0.9640300869941711,
#   0.9733357429504395,
#   0.9753042459487915,
#   0.9829992651939392,
#   0.9826413989067078,
#   0.9828203320503235,
#   0.9844309091567993,
#   0.9856836199760437,
#   0.9912312030792236,
#   0.9851467609405518,
#   0.9862204790115356,
#   0.9838940501213074],
#  'loss': [0.16850797832012177,
#   0.11381349712610245,
#   0.11537659913301468,
#   0.1062380000948906,
#   0.07747748494148254,
#   0.07854720205068588,
#   0.055844493210315704,
#   0.05312054604291916,
#   0.04454435780644417,
#   0.04906758666038513,
#   0.03981892019510269,
#   0.027302315458655357,
#   0.04068199172616005,
#   0.044833820313215256,
#   0.0428643524646759],
#  'val_accuracy': [0.8074445128440857,
#   0.8332140445709229,
#   0.8525411486625671,
#   0.8203292489051819,
#   0.856120228767395,
#   0.8532570004463196,
#   0.8231925368309021,
#   0.8210451006889343,
#   0.856120228767395,
# ...

# %%
import dill

with open('feature_extractor_dill.pkl', 'wb') as f:
    dill.dump(extractor, f)

# Later load it:
with open('feature_extractor_dill.pkl', 'rb') as f:
    extractor = dill.load(f)

# %%
from tensorflow.keras.models import load_model

# Load the model from .h5 file
model = load_model('my_trained_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 376, 40, 32)    │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 376, 40, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 188, 20, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 188, 20, 128)   │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
extractor
# Out:
# FeatureExtractor()

# %%
features = extractor.transform(["99192-4-0-55.wav"])

# %%
prediction = model.predict(features)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
predicted_class = np.argmax(prediction, axis=1)

label_mapping = {
    0: 'air_conditioner',
    1: 'car_horn',
    2: 'children_playing',
    3: 'dog_bark',
    4: 'drilling',
    5: 'engine_idling',
    6: 'gun_shot',
    7: 'jackhammer',
    8: 'siren',
    9: 'street_music'
}

# %%
print("Predicted class:", label_mapping[predicted_class[0]])
# Out:
# Predicted class: drilling

# %%
import librosa
from IPython.display import Audio

audio, sr = librosa.load("99192-4-0-55.wav", sr=None)

Audio(audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
